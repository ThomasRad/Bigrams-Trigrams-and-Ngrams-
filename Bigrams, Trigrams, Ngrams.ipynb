# %% [markdown]
# # Bigrams, Trigrams, and Ngrams

# %%
# Import packages

from nltk.util import bigrams, trigrams, ngrams

# %%
# Bigrams on the text we had. 

Jo_Bigrams = list(nltk.bigrams(Jo_token))
Jo_Bigrams
# Out:
# [('I', 'have'),
#  ('have', 'a'),
#  ('a', 'combination'),
#  ('combination', 'of'),
#  ('of', 'technical'),
#  ('technical', 'and'),
#  ('and', 'management'),
#  ('management', 'experience'),
#  ('experience', 'focused'),
#  ('focused', 'on'),
#  ('on', 'machine'),
#  ('machine', 'learning'),
#  ('learning', 'and'),
#  ('and', 'AI'),
#  ('AI', '.'),
#  ('.', 'I'),
#  ('I', 'was'),
#  ('was', 'awarded'),
#  ('awarded', 'multiple'),
#  ('multiple', 'times'),
#  ('times', 'during'),
#  ('during', 'my'),
#  ('my', 'graduate'),
#  ('graduate', 'MMAI'),
#  ('MMAI', 'studies'),
#  ('studies', '.'),
#  ('.', 'I'),
#  ('I', 'come'),
#  ('come', 'from'),
#  ('from', 'a'),
#  ('a', 'biophysics'),
#  ('biophysics', 'background'),
#  ('background', 'with'),
#  ('with', 'a'),
#  ('a', 'strong'),
#  ('strong', 'foundation'),
#  ('foundation', 'in'),
#  ('in', 'mathematics'),
#  ('mathematics', ','),
#  (',', 'statistics'),
#  ('statistics', ','),
#  (',', 'and'),
#  ('and', 'probability'),
# ...

# %%
# Now with Trigrams 

Jo_Trigrams = list(nltk.trigrams(Jo_token))
Jo_Trigrams
# Out:
# [('I', 'have', 'a'),
#  ('have', 'a', 'combination'),
#  ('a', 'combination', 'of'),
#  ('combination', 'of', 'technical'),
#  ('of', 'technical', 'and'),
#  ('technical', 'and', 'management'),
#  ('and', 'management', 'experience'),
#  ('management', 'experience', 'focused'),
#  ('experience', 'focused', 'on'),
#  ('focused', 'on', 'machine'),
#  ('on', 'machine', 'learning'),
#  ('machine', 'learning', 'and'),
#  ('learning', 'and', 'AI'),
#  ('and', 'AI', '.'),
#  ('AI', '.', 'I'),
#  ('.', 'I', 'was'),
#  ('I', 'was', 'awarded'),
#  ('was', 'awarded', 'multiple'),
#  ('awarded', 'multiple', 'times'),
#  ('multiple', 'times', 'during'),
#  ('times', 'during', 'my'),
#  ('during', 'my', 'graduate'),
#  ('my', 'graduate', 'MMAI'),
#  ('graduate', 'MMAI', 'studies'),
#  ('MMAI', 'studies', '.'),
#  ('studies', '.', 'I'),
#  ('.', 'I', 'come'),
#  ('I', 'come', 'from'),
#  ('come', 'from', 'a'),
#  ('from', 'a', 'biophysics'),
#  ('a', 'biophysics', 'background'),
# ...

# %%
# And now N grams 

Jo_Ngrams = list(nltk.ngrams(Jo_token,4))
Jo_Ngrams
# Out:
# [('I', 'have', 'a', 'combination'),
#  ('have', 'a', 'combination', 'of'),
#  ('a', 'combination', 'of', 'technical'),
#  ('combination', 'of', 'technical', 'and'),
#  ('of', 'technical', 'and', 'management'),
#  ('technical', 'and', 'management', 'experience'),
#  ('and', 'management', 'experience', 'focused'),
#  ('management', 'experience', 'focused', 'on'),
#  ('experience', 'focused', 'on', 'machine'),
#  ('focused', 'on', 'machine', 'learning'),
#  ('on', 'machine', 'learning', 'and'),
#  ('machine', 'learning', 'and', 'AI'),
#  ('learning', 'and', 'AI', '.'),
#  ('and', 'AI', '.', 'I'),
#  ('AI', '.', 'I', 'was'),
#  ('.', 'I', 'was', 'awarded'),
#  ('I', 'was', 'awarded', 'multiple'),
#  ('was', 'awarded', 'multiple', 'times'),
#  ('awarded', 'multiple', 'times', 'during'),
#  ('multiple', 'times', 'during', 'my'),
#  ('times', 'during', 'my', 'graduate'),
#  ('during', 'my', 'graduate', 'MMAI'),
#  ('my', 'graduate', 'MMAI', 'studies'),
# ...
